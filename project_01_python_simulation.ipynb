# %% [markdown]
# <a href="https://colab.research.google.com/github/adhishagc/quantum-inspired-genetic-algorithm-qiskit-implementation-for-tsp/blob/master/project_01_python_simulation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
